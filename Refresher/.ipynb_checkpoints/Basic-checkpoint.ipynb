# %% [markdown]
# # Python Basics

# %% [markdown]
# ## Variables

# %%
space_name = 'Space X'

# %%
print(space_name)
#space_name
# Out:
# Space X

# %% [markdown]
# ## Data Types

# %%
type('hello')
# Out:
# str

# %%
type(1)
# Out:
# int

# %%
type(1.0)
# Out:
# float

# %%
type(True)
# Out:
# bool

# %%
type([1])
# Out:
# list

# %%
type({'test'})
# Out:
# set

# %%
type({
    'name': 'Space X'
})
# Out:
# dict
